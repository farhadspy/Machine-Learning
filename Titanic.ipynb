# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# لود داده‌های آموزشی
data_train = pd.read_csv("C:/Users/Farhad/Desktop/python/Machine_Learning/train_Titanic.csv")
data_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# پیش‌پردازش داده‌های آموزشی
data_train.replace(["female", "male"], [0, 1], inplace=True)
data_train.fillna(0, inplace=True)

data_train.head(10)
# Out:
# C:\Users\Farhad\AppData\Local\Temp\ipykernel_5152\2154884811.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_train.replace(["female", "male"], [0, 1], inplace=True)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# ...

# %%
# آماده‌سازی داده‌های آموزشی
X_train = np.array(data_train[["Pclass", "Sex", "Age" , "SibSp", "Parch", "Fare"]])
Y_train = np.array(data_train["Survived"])

# %%
# تعریف مدل
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(6, activation='sigmoid'), # Input layer
    tf.keras.layers.Dense(6, activation='relu'), # Hidden layer 1
    tf.keras.layers.Dense(8, activation='sigmoid'), # Hidden layer 2
    tf.keras.layers.Dense(2, activation='softmax') # Output layer
])

# %%
# کامپایل مدل
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy']
            )

# %%
# آموزش مدل
output = model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4296 - loss: 0.8023
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6197 - loss: 0.6534
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6139 - loss: 0.6426
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6352 - loss: 0.6141
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6785 - loss: 0.6119
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6674 - loss: 0.5901
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7058 - loss: 0.5663
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6928 - loss: 0.5613
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7093 - loss: 0.5378
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6788 - loss: 0.5733
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7199 - loss: 0.5398
# Epoch 12/100
# ...

# %%
plt.plot(output.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
plt.plot(output.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
# لود و پیش‌پردازش داده‌های تست
data_test = pd.read_csv("C:/Users/Farhad/Desktop/python/Machine_Learning/test_Titanic.csv") 
data_test.replace(["female", "male"], [0, 1], inplace=True)
data_test.fillna(0, inplace=True)
X_test = np.array(data_test[["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare"]])
# Out:
# C:\Users\Farhad\AppData\Local\Temp\ipykernel_5152\2770913378.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_test.replace(["female", "male"], [0, 1], inplace=True)

# %%
# ارزیابی مدل روی داده‌های تست
Y_test_pred = model.predict(X_test)
Y_test_pred_classes = np.argmax(Y_test_pred, axis=1)  # تبدیل خروجی softmax به کلاس (0 یا 1)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
Y_test = np.array(data_test["Survived"])
test_loss, test_accuracy = model.evaluate(X_test, Y_test)
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5726 - loss: 0.8979
# Test accuracy: 0.5550

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.axhline(y=test_loss, color='r', label=f'Test Loss: {test_loss:.4f}')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.axhline(y=test_accuracy, color='b', label=f'Test Accuracy: {test_accuracy:.4f}')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
